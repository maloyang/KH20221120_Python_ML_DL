# %% [markdown]
# # MatPlotLib
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python
#
# - ref: https://matplotlib.org/
# - ref: http://www.aosabook.org/en/matplotlib.html
#     - https://matplotlib.org/stable/users/getting_started/

# %% [markdown]
# ## 我們假設你是使用 Anaconda，所以已經內建matplotlib
# - 如果沒有的話，可以使用指令安裝 `pip install matplotlib`
# ----

# %% [markdown]
# ### 第一個demo

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

data = [1, 2, 3, 4, 3, 2, 1]
plt.plot(data)
plt.show()

# %% [markdown]
# ### Style

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - OO-style

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
ax.plot(x, y);  # Plot some data on the axes.

# %% [markdown]
# - pyplot-style

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
plt.plot(x, y)

# %% [markdown]
# - figure的各部分說明
#
# ![img](img/anatomy.png)

# %% [markdown]
# ### 一維

# %%
x = np.arange(10)
plt.plot(x)

# %% [markdown]
# 如果是寫成獨立的程式 (.py 檔)，則需用下面程式來顯示圖形。
#
# ```
# plt.show()
# ```

# %% [markdown]
# ### 二維

# %%
x = np.random.rand(10, 2)
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x1ff9701b520>,
#  <matplotlib.lines.Line2D at 0x1ff9701b550>]

# %%
x
# Out:
# array([[0.37005075, 0.16444944],
#        [0.35383375, 0.82928624],
#        [0.64869321, 0.42514341],
#        [0.51626284, 0.21590557],
#        [0.75088749, 0.94716876],
#        [0.4286067 , 0.1262579 ],
#        [0.85970672, 0.03015143],
#        [0.75481759, 0.74730653],
#        [0.54333945, 0.91405917],
#        [0.32570036, 0.63060534]])

# %%
# 不是用numpy元件

x1 = [1, 3, 2, 5, 4]
x2 = [8, 7, 6, 5, 5]
plt.plot(x1)
plt.plot(x2)

# %% [markdown]
# ## 子圖 (Subplot)
#
# 參考資料：[Subplot Demo](http://matplotlib.org/examples/pylab_examples/subplots_demo.html)

# %%
plt.subplot(211)
x = np.arange(10)
plt.plot(x)
plt.subplot(212)
y = np.random.rand(10)
plt.plot(y)

# %%
plt.subplot(121)
x = np.arange(10)
plt.plot(x)
plt.subplot(122)
y = np.random.rand(10)
plt.plot(y)

# %%
plt.subplot(221)
x1 = np.random.rand(10)
plt.plot(x1, 'ro')
plt.subplot(222)
x2 = np.random.rand(10)
plt.plot(x2, 'b^')
plt.subplot(223)
x3 = np.random.rand(10)
plt.plot(x3, 'gx')
plt.subplot(224)
x4 = np.random.rand(10)
plt.plot(x4, 'k*')

# %% [markdown]
# ## 畫其他的圖表 (散布圖、餅圖、直方圖等)

# %%
# 請參考：http://matplotlib.org/examples/shapes_and_collections/scatter_demo.html
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# %%
# 請參考：http://matplotlib.org/examples/pie_and_polar_charts/pie_demo_features.html
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.2142507666786346,
#  1.134711077927507,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
# bar chart - 1
N = 10
y = np.random.randint(1, 10, size=N)
x = range(N)
width = 0.5
plt.bar(x, y, width, color="blue")
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# - xlim()設定x軸的刻度左右二側的極限值

# %%
# bar chart - 2
N = 10
y = np.random.randint(1, 10, size=N)
x = np.arange(N)
width = 0.5
plt.bar(x - 0.25, y, width, color="blue")
plt.xlim(-4, 10)
# Out:
# (-4.0, 10.0)

# %%
y
# Out:
# array([9, 2, 7, 5, 2, 2, 9, 2, 2, 6])

# %%
# histogram
x = np.random.randn(1000)
n_bins = 10

plt.hist(x, n_bins, color='g', rwidth=0.6)
# Out:
# (array([  9.,  29., 109., 209., 265., 198., 138.,  36.,   5.,   2.]),
#  array([-3.12001164, -2.42994613, -1.73988062, -1.04981511, -0.3597496 ,
#          0.33031591,  1.02038142,  1.71044693,  2.40051244,  3.09057795,
#          3.78064346]),
#  <BarContainer object of 10 artists>)
